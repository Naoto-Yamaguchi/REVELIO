# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("AnnotationDbi")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
#
# Installing package(s) 'AnnotationDbi'
#
# also installing the dependencies ‘rlang’, ‘bit’, ‘vctrs’, ‘bit64’, ‘blob’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’
#
#
# Warning message in install.packages(...):
# “installation of package ‘rlang’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘bit’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Biobase’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘S4Vectors’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘vctrs’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘bit64’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘IRanges’ had non-zero exit status”
# ...

# %%
#library(AnnotationDbi)
library(org.Hs.eg.db)
# Out:
# Error in library(org.Hs.eg.db): there is no package called ‘org.Hs.eg.db’
# Traceback:
#
# 1. library(org.Hs.eg.db)

# %%
library("AnnotationDbi")
# Out:
# Error in library("AnnotationDbi"): there is no package called ‘AnnotationDbi’
# Traceback:
#
# 1. library("AnnotationDbi")

# %%
library("hgu95av2.db")
# Out:
# Error in library("hgu95av2.db"): there is no package called ‘hgu95av2.db’
# Traceback:
#
# 1. library("hgu95av2.db")

# %%
BiocManager::available()
# Out:
#     [1] "A3"
#     [2] "a4"
#     [3] "a4Base"
#     [4] "a4Classif"
#     [5] "a4Core"
#     [6] "a4Preproc"
#     [7] "a4Reporting"
#     [8] "aaSEA"
#     [9] "AATtools"
#    [10] "ABACUS"
#    [11] "ABAData"
#    [12] "ABAEnrichment"
#    [13] "ABarray"
#    [14] "abbyyR"
#    [15] "abc"
#    [16] "abc.data"
#    [17] "ABC.RAP"
#    [18] "abcADM"
#    [19] "ABCanalysis"
#    [20] "abcdeFBA"
#    [21] "ABCoptim"
#    [22] "ABCp2"
#    [23] "abcrf"
#    [24] "abcrlda"
#    [25] "abctools"
#    [26] "abd"
#    [27] "abdiv"
#    [28] "abe"
#    [29] "abf2"
#    [30] "ABHgenotypeR"
#    [31] "abind"
#    [32] "abjutils"
#    [33] "abn"
#    [34] "abnormality"
#    [35] "abodOutlier"
#    [36] "ABPS"
#    [37] "abseqR"
#    [38] "AbsFilterGSEA"
#    [39] "AbSim"
#    [40] "ABSSeq"
#    [41] "abstractr"
#    [42] "abtest"
#    [43] "abundant"
#    [44] "Ac3net"
#    [45] "ACA"
#    [46] "acc"
#    [47] "accelerometry"
#    [48] "accelmissing"
#    [49] "accept"
# ...

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("biomaRt")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
#
# Installing package(s) 'biomaRt'
#
# also installing the dependencies ‘bit’, ‘rlang’, ‘bit64’, ‘blob’, ‘vctrs’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘hms’, ‘dbplyr’, ‘XML’, ‘AnnotationDbi’, ‘progress’, ‘BiocFileCache’, ‘rappdirs’
#
#
# Warning message in install.packages(...):
# “installation of package ‘bit’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rlang’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Biobase’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘S4Vectors’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘XML’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rappdirs’ had non-zero exit status”
# Warning message in install.packages(...):
# ...

# %%
library(biomaRt)
# Out:
# Error in library(biomaRt): there is no package called ‘biomaRt’
# Traceback:
#
# 1. library(biomaRt)

# %%
# packageがどこにインストールされているのかを確認
.libPaths()
# Out:
# [1] "/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/library"

# %%
# Packageは基本
# CRAN, Bioconductorを

# %%
help(package="AnnotationDbi")
# Out:
# Error in find.package(pkgName, lib.loc, verbose = verbose): there is no package called ‘AnnotationDbi’
# Traceback:
#
# 1. help(package = "AnnotationDbi")
# 2. library(help = package, lib.loc = lib.loc, character.only = TRUE)
# 3. find.package(pkgName, lib.loc, verbose = verbose)

# %%
library(dplyr)

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "package:dplyr"     "jupyter:irkernel"
#  [4] "package:stats"     "package:graphics"  "package:grDevices"
#  [7] "package:utils"     "package:datasets"  "package:methods"
# [10] "Autoloads"         "package:base"

# %%
help(package="dplyr")
# Out:
# Documentation for package ‘dplyr’
#
#
# 		Information on package ‘dplyr’
#
# Description:
#
# Type:               Package
# Package:            dplyr
# Title:              A Grammar of Data Manipulation
# Version:            0.8.0.1
# Authors@R:          c( person("Hadley", "Wickham", ,
#                     "hadley@rstudio.com", c("aut", "cre"), comment =
#                     c(ORCID = "0000-0003-4757-117X")), person("Romain",
#                     "Fran\u00e7ois", role = "aut", comment = c(ORCID =
#                     "0000-0002-2444-4226")), person("Lionel", "Henry",
#                     role = "aut"), person("Kirill", "M\u00fcller", role
#                     = "aut", comment = c(ORCID =
#                     "0000-0002-1416-3412")), person("RStudio", role =
#                     c("cph", "fnd")) )
# Description:        A fast, consistent tool for working with data frame
#                     like objects, both in memory and out of memory.
# ...

# %%
library(BiocManager)
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), ?BiocManager::install for help
#
# Bioconductor version '3.10' is out-of-date; the current release version '3.11'
#   is available with R version '4.0'; see https://bioconductor.org/install

# %%
R.version
# Out:
#                _
# platform       x86_64-apple-darwin13.4.0
# arch           x86_64
# os             darwin13.4.0
# system         x86_64, darwin13.4.0
# status
# major          3
# minor          6.1
# year           2019
# month          07
# day            05
# svn rev        76782
# language       R
# version.string R version 3.6.1 (2019-07-05)
# nickname       Action of the Toes

# %%
BiocManager::install("AnnotationDbi")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
#
# Installing package(s) 'AnnotationDbi'
#
# also installing the dependencies ‘rlang’, ‘bit’, ‘vctrs’, ‘bit64’, ‘blob’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’
#
#
# Warning message in install.packages(...):
# “installation of package ‘rlang’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘bit’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Biobase’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘S4Vectors’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘vctrs’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘bit64’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘IRanges’ had non-zero exit status”
# ...

# %%
BiocManager::version()
# Out:
# [1] ‘3.10’

# %%
Sys.setenv(R_LIBS_USER="/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/library")

# %%
Sys.getenv()
# Out:
# __CF_USER_TEXT_ENCODING
#                         0x1F5:0x1:0xE
# __KMP_REGISTERED_LIB_44324
#                         0x10ed696a8-cafe83bf-libomp.dylib
# __PYVENV_LAUNCHER__     /usr/local/Cellar/python/3.7.7/bin/python3.7
# Apple_PubSub_Socket_Render
#                         /private/tmp/com.apple.launchd.x7Qk0WzZWT/Render
# COLORFGBG               15;0
# COLORTERM               truecolor
# DYLD_FALLBACK_LIBRARY_PATH
#                         /Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/lib:/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib:/Users/naoto/.pyenv/versions/anaconda3-5.3.0/jre/lib/server
# EDITOR                  vi
# HOME                    /Users/naoto
# ITERM_PROFILE           Default
# ITERM_SESSION_ID        w0t0p0:EE753AF0-42C2-430A-B68E-23470A6008CC
# JPY_PARENT_PID          41947
# KERNEL_LAUNCH_TIMEOUT   40
# LANG                    ja_JP.UTF-8
# LC_CTYPE                ja_JP.UTF-8
# LESS                    -R
# LN_S                    ln -s
# ...

# %%
path = "/Library/Frameworks/R.framework/Versions/3.5/Resources/library"
#path = "~/Library/R/3.6/library"
#path = .libPaths()
library.path <- path

# %%
library("AnnotationDbi")
# Out:
# Error in library("AnnotationDbi"): there is no package called ‘AnnotationDbi’
# Traceback:
#
# 1. library("AnnotationDbi")

# %%
.libPaths()
# Out:
# [1] "/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/library"

# %%
library.path
# Out:
# [1] "/Library/Frameworks/R.framework/Versions/3.5/Resources/library"

# %%
library.dynam
# Out:
# function (chname, package, lib.loc, verbose = getOption("verbose"),
#     file.ext = .Platform$dynlib.ext, ...)
# {
#     dll_list <- .dynLibs()
#     if (missing(chname) || !nzchar(chname))
#         return(dll_list)
#     package
#     lib.loc
#     r_arch <- .Platform$r_arch
#     chname1 <- paste0(chname, file.ext)
#     for (pkg in find.package(package, lib.loc, verbose = verbose)) {
#         DLLpath <- if (nzchar(r_arch))
#             file.path(pkg, "libs", r_arch)
#         else file.path(pkg, "libs")
#         file <- file.path(DLLpath, chname1)
#         if (file.exists(file))
#             break
#         else file <- ""
#     }
#     if (file == "")
#         if (.Platform$OS.type == "windows")
#             stop(gettextf("DLL %s not found: maybe not installed for this architecture?",
#                 sQuote(chname)), domain = NA)
#         else stop(gettextf("shared object %s not found", sQuote(chname1)),
#             domain = NA)
# ...

# %%
library(xfun)
# Out:
# Error in library(xfun): there is no package called ‘xfun’
# Traceback:
#
# 1. library(xfun)

# %%
search()
# Out:
#  [1] ".GlobalEnv"           "package:BiocGenerics" "package:parallel"
#  [4] "package:stats4"       "package:BiocManager"  "package:dplyr"
#  [7] "jupyter:irkernel"     "package:stats"        "package:graphics"
# [10] "package:grDevices"    "package:utils"        "package:datasets"
# [13] "package:methods"      "Autoloads"            "package:base"

# %%
.libPaths()
# Out:
# [1] "/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/library"

# %%
Sys.getenv("R_LIBS_USER")
# Out:
# [1] "/Users/naoto/.pyenv/versions/anaconda3-5.3.0/lib/R/library"

# %%
BiocManager::install("biomaRt")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
#
# Installing package(s) 'biomaRt'
#
# also installing the dependencies ‘bit’, ‘rlang’, ‘bit64’, ‘blob’, ‘vctrs’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘hms’, ‘dbplyr’, ‘XML’, ‘AnnotationDbi’, ‘progress’, ‘BiocFileCache’, ‘rappdirs’
#
#
# Warning message in install.packages(...):
# “installation of package ‘bit’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rlang’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Biobase’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘S4Vectors’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘XML’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rappdirs’ had non-zero exit status”
# Warning message in install.packages(...):
# ...
